# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


df = pd.read_csv('../data/diabetic_readmission_data.csv')
df.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0       2278392      8222157        Caucasian  Female    [0-10)      ?
# 1        149190     55629189        Caucasian  Female   [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3        500364     82442376        Caucasian    Male   [30-40)      ?
# 4         16680     42519267        Caucasian    Male   [40-50)      ?
# 5         35754     82637451        Caucasian    Male   [50-60)      ?
# 6         55842     84259809        Caucasian    Male   [60-70)      ?
# 7         63768    114882984        Caucasian    Male   [70-80)      ?
# 8         12522     48330783        Caucasian  Female   [80-90)      ?
# 9         15738     63555939        Caucasian  Female  [90-100)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# ...

# %%
# There are 101,766 rows and 50 columns
print(df.shape)
# Out:
# (101766, 50)

# %%
# Examine data
# show all columns
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
# Because there are many of hiden columns & hiden rows,
#in order to have an overview of dataframe, try to see through all of them
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
df.head(25)
# Out:
#     encounter_id  patient_nbr             race  gender       age weight  \
# 0        2278392      8222157        Caucasian  Female    [0-10)      ?
# 1         149190     55629189        Caucasian  Female   [10-20)      ?
# 2          64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3         500364     82442376        Caucasian    Male   [30-40)      ?
# 4          16680     42519267        Caucasian    Male   [40-50)      ?
# 5          35754     82637451        Caucasian    Male   [50-60)      ?
# 6          55842     84259809        Caucasian    Male   [60-70)      ?
# 7          63768    114882984        Caucasian    Male   [70-80)      ?
# 8          12522     48330783        Caucasian  Female   [80-90)      ?
# 9          15738     63555939        Caucasian  Female  [90-100)      ?
# 10         28236     89869032  AfricanAmerican  Female   [40-50)      ?
# 11         36900     77391171  AfricanAmerican    Male   [60-70)      ?
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
# encounter_id                101766 non-null int64
# patient_nbr                 101766 non-null int64
# race                        101766 non-null object
# gender                      101766 non-null object
# age                         101766 non-null object
# weight                      101766 non-null object
# admission_type_id           101766 non-null int64
# discharge_disposition_id    101766 non-null int64
# admission_source_id         101766 non-null int64
# time_in_hospital            101766 non-null int64
# payer_code                  101766 non-null object
# medical_specialty           101766 non-null object
# num_lab_procedures          101766 non-null int64
# num_procedures              101766 non-null int64
# num_medications             101766 non-null int64
# number_outpatient           101766 non-null int64
# ...

# %%
# examine the common stats of numeric columns
print(df.describe())
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
# loop through the data of each column, find the column has value of cell which is object =='?' then count
for col in df.columns:
    if df[col].dtype == object:
         print(col, df[col][df[col] == '?'].count())
# Out:
# race 2273
# gender 0
# age 0
# weight 98569
# payer_code 40256
# medical_specialty 49949
# diag_1 21
# diag_2 358
# diag_3 1423
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0

# %%
# Because 'readmitted' is a very important feature to look through therefore need to check to see all possible value of data in column
df['readmitted'].unique()
# Out:
# array(['NO', '>30', '<30'], dtype=object)

# %%
# To compare b/w patient_nbr & readmitted & encounter_id figures:
print(len(df['patient_nbr'].unique()))
print(len(df['encounter_id'].unique()))
# Out:
# 71518
# 101766

# %%
# Because gender is a important feature to look through therefore need to check to see all possible value of data in column
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Unknown/Invalid'], dtype=object)

# %%
# to count how many missing data cell in gender column
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# gender 3

# %%
# Because weight, payer_code, medical_specialty missing value are more than 50%
df.drop(['weight', 'payer_code', 'medical_specialty'], axis=1, inplace = True)
df
# Out:
#         encounter_id  patient_nbr             race  gender       age  \
# 0            2278392      8222157        Caucasian  Female    [0-10)
# 1             149190     55629189        Caucasian  Female   [10-20)
# 2              64410     86047875  AfricanAmerican  Female   [20-30)
# 3             500364     82442376        Caucasian    Male   [30-40)
# 4              16680     42519267        Caucasian    Male   [40-50)
# 5              35754     82637451        Caucasian    Male   [50-60)
# 6              55842     84259809        Caucasian    Male   [60-70)
# 7              63768    114882984        Caucasian    Male   [70-80)
# 8              12522     48330783        Caucasian  Female   [80-90)
# 9              15738     63555939        Caucasian  Female  [90-100)
# 10             28236     89869032  AfricanAmerican  Female   [40-50)
# 11             36900     77391171  AfricanAmerican    Male   [60-70)
# 12             40926     85504905        Caucasian  Female   [40-50)
# ...

# %%
# There is no duplicated value in column patient_nbr
df[df.duplicated(keep=False)].sort_values(by='patient_nbr')
# Out:
# Empty DataFrame
# Columns: [encounter_id, patient_nbr, race, gender, age, admission_type_id, discharge_disposition_id, admission_source_id, time_in_hospital, num_lab_procedures, num_procedures, num_medications, number_outpatient, number_emergency, number_inpatient, diag_1, diag_2, diag_3, number_diagnoses, max_glu_serum, A1Cresult, metformin, repaglinide, nateglinide, chlorpropamide, glimepiride, acetohexamide, glipizide, glyburide, tolbutamide, pioglitazone, rosiglitazone, acarbose, miglitol, troglitazone, tolazamide, examide, citoglipton, insulin, glyburide-metformin, glipizide-metformin, glimepiride-pioglitazone, metformin-rosiglitazone, metformin-pioglitazone, change, diabetesMed, readmitted]
# Index: []

# %%
# df['patient_nbr'][df['readmitted'] == '>30']
df['patient_nbr'][df['readmitted'] == '>30'].count()
# Out:
# 35545

# %%
##### Because 'readmitted' is a very important feature to look through therefore need to check to see all possible value of data in column
reamitted_values = df['readmitted'].unique()
print(reamitted_values)
# Out:
# ['NO' '>30' '<30']

# %%
# df.groupby('time_in_hospital')['readmitted'].mean().head()
#df.groupby(['patient_nbr','readmitted']).head()

# %%
#df[['patient_nbr', 'encounter_id', 'time_in_hospital', 'readmitted']].head(8)
#df[['patient_nbr', 'encounter_id', 'time_in_hospital', 'readmitted']].groupby(['patient_nbr','readmitted']).head()
df.groupby(['time_in_hospital', 'readmitted'])['patient_nbr', 'encounter_id'].count()
# Out:
#                              patient_nbr  encounter_id
# time_in_hospital readmitted
# 1                <30                1162          1162
#                  >30                4471          4471
#                  NO                 8575          8575
# 2                <30                1712          1712
#                  >30                5919          5919
#                  NO                 9593          9593
# 3                <30                1894          1894
#                  >30                6085          6085
#                  NO                 9777          9777
# 4                <30                1644          1644
#                  >30                5064          5064
#                  NO                 7216          7216
# 5                <30                1199          1199
#                  >30                3586          3586
#                  NO                 5181          5181
# 6                <30                 949           949
# ...

# %%
df.groupby(['time_in_hospital', 'gender'])['patient_nbr'].count()
# Out:
# time_in_hospital  gender
# 1                 Female             6917
#                   Male               7289
#                   Unknown/Invalid       2
# 2                 Female             9064
#                   Male               8160
# 3                 Female             9606
#                   Male               8150
# 4                 Female             7702
#                   Male               6222
# 5                 Female             5488
#                   Male               4478
# 6                 Female             4274
#                   Male               3265
# 7                 Female             3232
#                   Male               2627
# 8                 Female             2414
#                   Male               1976
#                   Unknown/Invalid       1
# 9                 Female             1663
#                   Male               1339
# 10                Female             1290
#                   Male               1052
# ...

# %%
dict_age_under = {'[0-10)':10, '[10-20)':20, '[20-30)':30, '[30-40)':40, '[40-50)':50,
                  '[50-60)':60, '[60-70)':70,'[70-80)':80,'[80-90)':90, '[90-100)':100}
df['age'] = df['age'].map(dict_age_under)
#df.groupby(['time_in_hospital', 'age'])['patient_nbr'].mean()

# %%
#add new feature age_under
df['age_under'] = df['age'].replace('[0-10)', 10)
df['age_under'] = df['age'].replace('[0-20)', 20)
df['age_under'] = df['age'].replace('[0-30)', 30)
df['age_under'] = df['age'].replace('[0-40)', 40)
df['age_under'] = df['age'].replace('[0-50)', 50)
df['age_under'] = df['age'].replace('[0-60)', 60)
df['age_under'] = df['age'].replace('[0-70)', 70)
df['age_under'] = df['age'].replace('[0-80)', 80)
df['age_under'] = df['age'].replace('[0-90)', 90)
df['age_under'] = df['age'].replace('[0-100)', 100)

print(df['age_under'])
# Out:
# 0          10
# 1          20
# 2          30
# 3          40
# 4          50
# 5          60
# 6          70
# 7          80
# 8          90
# 9         100
# 10         50
# 11         70
# 12         50
# 13         90
# 14         70
# 15         70
# 16         60
# 17         60
# 18         80
# 19         80
# 20         60
# 21         70
# 22         80
# 23         90
# 24         80
# 25         60
# 26         90
# 27         60
# 28         30
# 29         90
#          ...
# 101736     70
# 101737     50
# 101738     80
# 101739     80
# 101740     50
# 101741    100
# 101742     80
# 101743     90
# 101744     90
# 101745     60
# 101746     80
# 101747     80
# 101748     50
# 101749     80
# 101750     90
# 101751     80
# 101752     50
# 101753     50
# 101754     80
# 101755     50
# 101756     70
# 101757     80
# 101758     90
# 101759     90
# 101760     70
# 101761     80
# 101762     90
# 101763     80
# 101764     90
# 101765     80
# ...

# %%
df.head(30)
# Out:
#     encounter_id  patient_nbr             race  gender  age  \
# 0        2278392      8222157        Caucasian  Female   10
# 1         149190     55629189        Caucasian  Female   20
# 2          64410     86047875  AfricanAmerican  Female   30
# 3         500364     82442376        Caucasian    Male   40
# 4          16680     42519267        Caucasian    Male   50
# 5          35754     82637451        Caucasian    Male   60
# 6          55842     84259809        Caucasian    Male   70
# 7          63768    114882984        Caucasian    Male   80
# 8          12522     48330783        Caucasian  Female   90
# 9          15738     63555939        Caucasian  Female  100
# 10         28236     89869032  AfricanAmerican  Female   50
# 11         36900     77391171  AfricanAmerican    Male   70
# 12         40926     85504905        Caucasian  Female   50
# 13         42570     77586282        Caucasian    Male   90
# 14         62256     49726791  AfricanAmerican  Female   70
# ...

# %%
# examine the common stats of numeric columns to check if age_under is okay
print(df.describe())
# Out:
#        encounter_id   patient_nbr            age  admission_type_id  \
# count  1.017660e+05  1.017660e+05  101766.000000      101766.000000
# mean   1.652016e+08  5.433040e+07      70.967022           2.024006
# std    1.026403e+08  3.869636e+07      15.940838           1.445403
# min    1.252200e+04  1.350000e+02      10.000000           1.000000
# 25%    8.496119e+07  2.341322e+07      60.000000           1.000000
# 50%    1.523890e+08  4.550514e+07      70.000000           1.000000
# 75%    2.302709e+08  8.754595e+07      80.000000           3.000000
# max    4.438672e+08  1.895026e+08     100.000000           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# ...

# %%
#Removing duplicated
#df = df[df.duplicated

# %%
#Rechecking duplicated data
#Duplicates should no longer exist
#df[df.duplicated(keep=False)].sort_values(by='business_id')

# %%
# df.groupby('time_in_hospital')['readmitted'].mean().head()
df.groupby(['time_in_hospital','readmitted']).sum()
# Out:
#                               encounter_id   patient_nbr     age  \
# time_in_hospital readmitted
# 1                <30          201770615962   64669046985   79400
#                  >30          733590957712  258352510031  308800
#                  NO          1505474759480  449777153883  579300
# 2                <30          288939077942   96358854262  118190
#                  >30          963443505460  342361386776  412330
#                  NO          1646758472046  498385987251  647450
# 3                <30          321967502782  106686236663  135490
#                  >30         1002726114110  361702693280  437530
#                  NO          1707487572212  522237321011  680050
# 4                <30          279093072704   93100706559  120050
#                  >30          823256209400  298562891057  365910
#                  NO          1212277766578  371556487862  513770
# 5                <30          195938418862   66457980874   88250
# ...

# %%
drop_Idx = set(df[(df['diag_1'] == '?') & (df['diag_2'] == '?') & (df['diag_3'] == '?')].index)
drop_Idx = drop_Idx.union(set(df['gender'][df['gender'] == 'Unknown/Invalid'].index))
new_Idx = list(set(df.index) - set(drop_Idx))
df.drop(drop_Idx)
# Out:
#         encounter_id  patient_nbr             race  gender  age  \
# 0            2278392      8222157        Caucasian  Female   10
# 1             149190     55629189        Caucasian  Female   20
# 2              64410     86047875  AfricanAmerican  Female   30
# 3             500364     82442376        Caucasian    Male   40
# 4              16680     42519267        Caucasian    Male   50
# 5              35754     82637451        Caucasian    Male   60
# 6              55842     84259809        Caucasian    Male   70
# 7              63768    114882984        Caucasian    Male   80
# 8              12522     48330783        Caucasian  Female   90
# 9              15738     63555939        Caucasian  Female  100
# 10             28236     89869032  AfricanAmerican  Female   50
# 11             36900     77391171  AfricanAmerican    Male   70
# 12             40926     85504905        Caucasian  Female   50
# 13             42570     77586282        Caucasian    Male   90
# ...

# %%
df.head(20)
# Out:
#     encounter_id  patient_nbr             race  gender  age  \
# 0        2278392      8222157        Caucasian  Female   10
# 1         149190     55629189        Caucasian  Female   20
# 2          64410     86047875  AfricanAmerican  Female   30
# 3         500364     82442376        Caucasian    Male   40
# 4          16680     42519267        Caucasian    Male   50
# 5          35754     82637451        Caucasian    Male   60
# 6          55842     84259809        Caucasian    Male   70
# 7          63768    114882984        Caucasian    Male   80
# 8          12522     48330783        Caucasian  Female   90
# 9          15738     63555939        Caucasian  Female  100
# 10         28236     89869032  AfricanAmerican  Female   50
# 11         36900     77391171  AfricanAmerican    Male   70
# 12         40926     85504905        Caucasian  Female   50
# 13         42570     77586282        Caucasian    Male   90
# 14         62256     49726791  AfricanAmerican  Female   70
# ...

# %%
df['citoglipton'].unique()
# Out:
# array(['No'], dtype=object)

# %%
df['examide'].unique()
# Out:
# array(['No'], dtype=object)

# %%
df = df.drop(['citoglipton', 'examide'], axis = 1)

# %%
df['diag_1'].head(15)
# Out:
# 0     250.83
# 1        276
# 2        648
# 3          8
# 4        197
# 5        414
# 6        414
# 7        428
# 8        398
# 9        434
# 10     250.7
# 11       157
# 12       428
# 13       428
# 14       518
# Name: diag_1, dtype: object

# %%
#This transforms the data into a person by person spreadsheet and what stars they gave various restaurants
#Most values are NaN (null or missing) because people only review a few restaurants of those that exist
#usr_reviews = df.pivot(index='user_id', columns='business_id', values='stars')
#usr_reviews.head()

# %%
subset1 = df.loc[(df['readmitted'] != 'NO')]
print(type(subset1))
subset1
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         encounter_id  patient_nbr             race  gender  age  \
# 1             149190     55629189        Caucasian  Female   20
# 5              35754     82637451        Caucasian    Male   60
# 7              63768    114882984        Caucasian    Male   80
# 10             28236     89869032  AfricanAmerican  Female   50
# 11             36900     77391171  AfricanAmerican    Male   70
# 12             40926     85504905        Caucasian  Female   50
# 14             62256     49726791  AfricanAmerican  Female   70
# 16             77076     92519352  AfricanAmerican    Male   60
# 18             89682    107389323  AfricanAmerican    Male   80
# 23            183930    107400762        Caucasian  Female   90
# 27            248916    115196778        Caucasian  Female   60
# 28            250872     41606064        Caucasian    Male   30
# 29            252822     18196434        Caucasian  Female   90
# ...
