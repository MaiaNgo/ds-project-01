# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("../data/allcauseunplanned30-dayhospitalreadmissionratecalifornia201117.csv")
df
# Out:
#      Year          Strata             Strata Name        County  \
# 0    2011         Overall                 Overall         State
# 1    2011             Age          18 to 44 years         State
# 2    2011             Age          45 to 64 years         State
# 3    2011             Age      65 years and above         State
# 4    2011             Sex                    Male         State
# 5    2011             Sex                  Female         State
# 6    2011  Race-Ethnicity                   White         State
# 7    2011  Race-Ethnicity                Hispanic         State
# 8    2011  Race-Ethnicity        African-American         State
# 9    2011  Race-Ethnicity  Asian/Pacific Islander         State
# 10   2011  Race-Ethnicity         Native American         State
# 11   2011  Race-Ethnicity           Other/Unknown         State
# 12   2011  Expected Payer                MediCare         State
# 13   2011  Expected Payer                Medi-Cal         State
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Year          Strata             Strata Name        County  \
# 0    2011         Overall                 Overall         State
# 1    2011             Age          18 to 44 years         State
# 2    2011             Age          45 to 64 years         State
# 3    2011             Age      65 years and above         State
# 4    2011             Sex                    Male         State
# 5    2011             Sex                  Female         State
# 6    2011  Race-Ethnicity                   White         State
# 7    2011  Race-Ethnicity                Hispanic         State
# 8    2011  Race-Ethnicity        African-American         State
# 9    2011  Race-Ethnicity  Asian/Pacific Islander         State
# 10   2011  Race-Ethnicity         Native American         State
# 11   2011  Race-Ethnicity           Other/Unknown         State
# 12   2011  Expected Payer                MediCare         State
# ...
