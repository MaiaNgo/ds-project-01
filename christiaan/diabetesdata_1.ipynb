# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("../data/diabetic_readmission_data.csv")
df.drop(['weight', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id','payer_code','encounter_id', 'patient_nbr'], axis=1, inplace = True)
df
# Out:
#                    race  gender       age  time_in_hospital  \
# 0             Caucasian  Female    [0-10)                 1
# 1             Caucasian  Female   [10-20)                 3
# 2       AfricanAmerican  Female   [20-30)                 2
# 3             Caucasian    Male   [30-40)                 2
# 4             Caucasian    Male   [40-50)                 1
# 5             Caucasian    Male   [50-60)                 3
# 6             Caucasian    Male   [60-70)                 4
# 7             Caucasian    Male   [70-80)                 5
# 8             Caucasian  Female   [80-90)                13
# 9             Caucasian  Female  [90-100)                12
# 10      AfricanAmerican  Female   [40-50)                 9
# 11      AfricanAmerican    Male   [60-70)                 7
# 12            Caucasian  Female   [40-50)                 7
# 13            Caucasian    Male   [80-90)                10
# 14      AfricanAmerican  Female   [60-70)                 1
# ...
